# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Loading and exploring data

# %%
df = pd.read_excel('data.xlsx')

# %%
df
# Out:
#         V_NUMPERIOD   ID_EMPRESA  sector  Departamento_ct  ntrab_tc_indet  \
# 0            202404  6UV9S7A9Q3E       6                3              65
# 1            202404  3UZ8X9S7N2B       3               14             177
# 2            202412  4YW1B4A2Y0S       1               18              68
# 3            202406  4YN2G7K5D9Q       5               11              71
# 4            202407  8NU3W0K7K5H       4                4              75
# ...             ...          ...     ...              ...             ...
# 119994       202306  0IJ3J7P0F8P       4               20              45
# 119995       202307  5UV8H0J5V8O       1                1              79
# 119996       202302  4QO5Y4A2N0I       3                7             169
# 119997       202301  0MI8A7G8F2N       3               13              58
# 119998       202409  6QT4X0I0L9G       6                9             105
#
#         ntrab_tc_nattemp  ntrab_tc_natacc  ntrab_tc_obrserv  ntrab_tc_tiempar  \
# ...

# %%
df['sst'].value_counts()
# Out:
# sst
# 1    119416
# 0       583
# Name: count, dtype: int64

# %%
dicc = pd.read_excel('Diccionario.xlsx')

# %%
dicc
# Out:
#                                            Unnamed: 0  \
# 0   Nombre del Dataset: Planilla Electrónica de Em...
# 1                                                 NaN
# 2                                            Variable
# 3                                         V_NUMPERIOD
# 4                                          ID_EMPRESA
# 5                                              sector
# 6                                     Departamento_ct
# 7                                      ntrab_tc_indet
# 8                                    ntrab_tc_nattemp
# 9                                     ntrab_tc_natacc
# 10                                   ntrab_tc_obrserv
# 11                                   ntrab_tc_tiempar
# 12                                     ntrab_tc_otros
# 13                                    ntrab_tc_noprec
# 14                                   ntrab_rl_privgen
# 15                                     ntrab_rl_micro
# ...
